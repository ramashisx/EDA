# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
zori = pd.read_csv("Metro_zori_sm_month.csv")
zhvi = pd.read_csv("Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
zhvf = pd.read_csv("Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
invt = pd.read_csv("Metro_invt_fs_uc_sfrcondo_sm_month.csv")
sales = pd.read_csv("Metro_sales_count_now_uc_sfrcondo_month.csv")
list = pd.read_csv("Metro_mlp_uc_sfrcondo_sm_month.csv")

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90, fontsize=5)
plt.plot(zori.iloc[0,5:])

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90, fontsize=5)
plt.plot(zhvi.iloc[0,5:])

# %%
zhvf
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName    BaseDate  \
# 0      102001         0    United States    country       NaN  2022-08-31
# 1      394913         1     New York, NY        msa        NY  2022-08-31
# 2      753899         2  Los Angeles, CA        msa        CA  2022-08-31
# 3      394463         3      Chicago, IL        msa        IL  2022-08-31
# 4      394514         4       Dallas, TX        msa        TX  2022-08-31
# ..        ...       ...              ...        ...       ...         ...
# 892    753929       923       Zapata, TX        msa        TX  2022-08-31
# 893    394743       924    Ketchikan, AK        msa        AK  2022-08-31
# 894    753874       925        Craig, CO        msa        CO  2022-08-31
# 895    394767       926       Lamesa, TX        msa        TX  2022-08-31
# 896    395188       927       Vernon, TX        msa        TX  2022-08-31
#
#      2022-09-30  2022-11-30  2023-08-31
# ...

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90, fontsize=5)
plt.plot(invt.iloc[0,5:])

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90, fontsize=5)
plt.plot(list.iloc[0,5:])

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90, fontsize=5)
plt.plot(sales.iloc[0,5:])
